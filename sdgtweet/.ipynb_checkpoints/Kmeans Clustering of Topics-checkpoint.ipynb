# %%
#Data Structures
import pandas as pd
import numpy as np
#Kmeans
from sklearn.cluster import KMeans
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer
#Visualization
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from wordcloud import WordCloud
plt.style.use('seaborn-pastel')
#Random State
random_state = 777
tknzr = TweetTokenizer()
stopwords = stopwords.words('english')

# %%
#Read in Clean Tweets 
df = pd.read_csv('cleaned_tweets17SDG.csv', lineterminator='\n',index_col = 0)

# %%
#Get Rid of NaN
df = df[~df.clean_tweet.isnull()]

# %%
df['clean_tweet'] = df['clean_tweet'].drop_duplicates()

# %%
df = df[~df.clean_tweet.isnull()]

# %%
# #Create Individual DFs
# for sdg in range(1,18):
#     locals()['df_' + f'{sdg}'] = df[(df['sdg'] == sdg)]

# %%
#Look and drop duplicates again 
# df_1['clean_tweet'] = df_1['clean_tweet'].drop_duplicates()

# %%
# #Drop NaNs will redo cleaning something wrong with text preprocessing 
# df_1 = df_1[~df_1.clean_tweet.isnull()]

# %%
#Vectorize Tweets 
tfidf_vec = TfidfVectorizer(stop_words = stopwords)
features = tfidf_vec.fit_transform(df.clean_tweet.values)

# %%
#Within Cluster Sum of Squares find optimal K 
wcss = []
for i in range(1, 20):
    kmeans = KMeans(n_clusters = i, 
                    random_state = random_state,max_iter=300,
                   init ='k-means++')
    kmeans.fit(features)
    wcss.append(kmeans.inertia_)

# %%
#Plot Elbow 
plt.figure(figsize=(8, 6), dpi=50)
plt.plot(range(1,20),wcss)
plt.title('Elbow Method')
plt.xlabel('NO. Clusters')
plt.ylabel('Within Clusters Sum of Squares')
plt.show()

# %%
#Elbow Suggests 2 
model = KMeans(n_clusters = 2, 
               random_state = random_state,max_iter=300, 
               init ='k-means++')
model.fit(features)
# Out:
# KMeans(n_clusters=2, random_state=777)

# %%
kmean_indices = model.fit_predict(features)

# %%
#Plot Clusters use PCA to reduce Dimensions 
pca = PCA(n_components=2)
scatter_plot_points = pca.fit_transform(features.toarray())

colors = ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn']

x_axis = [o[0] for o in scatter_plot_points]
y_axis = [o[1] for o in scatter_plot_points]
fig, ax = plt.subplots(figsize=(8,6), dpi = 80)

ax.scatter(x_axis, y_axis, c=[colors[d] for d in kmean_indices])
#too much text to annotate
# for i, txt in enumerate(df_1_list):
#     ax.annotate(txt, (x_axis[i], y_axis[i]))
plt.show()

# %%
#Label text 
labels=model.labels_
df1_list = df_1.clean_tweet.to_list()
tweet_df = pd.DataFrame(list(zip(df1_list,labels)),columns=['tweet','cluster'])
print(tweet_df.sort_values(by=['cluster']))
# Out:
#                                                   tweet  cluster
# 3773  really i m a liberal and not in any cult but i...        0
# 2006  you mean like when half or more didn t show up...        0
# 1301  nicola sturgeon has a record of shame when it ...        0
# 5016  can you believe what s going on biden actually...        0
# 388   the pro life party that actually doesn t reall...        0
# ...                                                 ...      ...
# 1962  senator scott what world do you live in the us...        1
# 1961  he is going to cut poverty by importing hundre...        1
# 1960  india is a huge country not other countries pr...        1
# 1968  would you like us to go back to when president...        1
# 5334  there s no good reason other than greed why in...        1
#
# [5335 rows x 2 columns]

# %%
#Plot word Cloud 
result={'cluster':labels,'tweet':df1_list}
result=pd.DataFrame(result)
for k in range(0,2):
    s=result[result.cluster==k]
    text=s['tweet'].str.cat(sep=' ')
    text=text.lower()
    text=' '.join([word for word in text.split()])
    wordcloud = WordCloud(max_font_size=50, max_words=100,
                          background_color="white").generate(text)
    print('Cluster: {}'.format(k))

    plt.figure(figsize=(10,10), dpi = 60)
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()
# Out:
# Cluster: 0
# Cluster: 1
