# %%
from pygooglenews import GoogleNews
from newspaper import Article
from newspaper import Config
import pandas as pd
import nltk
#config will allow us to access the specified url for which we are #not authorized. Sometimes we may get 403 client error while parsing #the link to download the article.
nltk.download('punkt')
gn = GoogleNews()
# Out:
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1123)>

# %%
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'
config = Config()
config.browser_user_agent = user_agent

# %%
begin_months2020 = ['01/01/2020', '02/01/2020', '03/01/2020', '04/01/2020','05/01/2020', 
                '06/01/2020', '07/01/2020', '08/01/2020', '09/01/2020', '10/01/2020', 
                '11/01/2020', '12/01/2020']
end_months2020 = ['01/31/2020', '02/29/2020', '03/31/2020', '04/30/2020','05/31/2020', 
                '06/30/2020', '07/31/2020', '08/31/2020', '09/30/2020', 
              '10/31/2020', '11/30/2020', '12/31/2020']

# %%
begin_months2019 = ['01/01/2018', '02/01/2018', '03/01/2018', '04/01/2018','05/01/2018', 
                '06/01/2018', '07/01/2018', '08/01/2018', '09/01/2018', '10/01/2018', '11/01/2018', '12/01/2018']
end_months2019 = ['01/31/2018', '02/28/2018', '03/31/2018', '04/30/2018','05/31/2018', 
                '06/30/2018', '07/31/2018', '08/31/2018', '09/30/2018', '10/31/2018', '11/30/2018', '12/31/2018']

# %%
begin_months2018 = ['01/01/2018', '02/01/2018', '03/01/2018', '04/01/2018','05/01/2018', 
                '06/01/2018', '07/01/2018', '08/01/2018', '09/01/2018', '10/01/2018', '11/01/2018', '12/01/2018']
end_months2018 = ['01/31/2018', '02/28/2018', '03/31/2018', '04/30/2018','05/31/2018', 
                '06/30/2018', '07/31/2018', '08/31/2018', '09/30/2018', '10/31/2018', '11/30/2018', '12/31/2018']

# %%
#17 SDGS

# %%
#no+poverty
#zero+hunger
#good+health+well+being
#quality+education
#gender+equality
#clean+water+sanitation
#affordable+clean+energy
#decent+work+economic+growth
#industry+innovation+infrastructure
#reduced+inequalities
#sustainable+cities+communities
#responsibile+consumption+production ########
#climate+action
#life+below+water
#life+on+land
#peace+justice+strong+institution
#partnerships+for+the+goals

# %%
news_list =[]
for x in range(len(begin_months2020)):
    s = gn.search('intitle:sdg+9', from_ = begin_months2020[x], to_ = end_months2020[x])
    for ind in range(len(s['entries'])):
        dict={}
        article = Article(s['entries'][ind]['link'],config=config)
        article.download()
        try:
            article.parse()
            article.nlp()
            dict['Link'] = s['entries'][ind]['link']
            dict['Date']=s['entries'][ind]['published']
            dict['Media']=s['entries'][ind]['source']['title']
            dict['Title']=article.title
            dict['Article']=article.text
            dict['Summary']=article.summary
            news_list.append(dict) 
        except:
            pass
news_df=pd.DataFrame(news_list)
news_df.to_csv('goognewssdg_9_2020.csv')
news_df
# Out:
#                                                   Link  \
# 0    https://sdg.iisd.org/commentary/guest-articles...
# 1    http://sdg.iisd.org/news/report-highlights-ide...
# 2    http://sdg.iisd.org/news/first-global-refugee-...
# 3    http://sdg.iisd.org/news/peru-shows-how-data-m...
# 4    https://sdg.iisd.org/news/six-countries-launch...
# ..                                                 ...
# 255  https://www.standard-freeholder.com/news/local...
# 256  https://economist.com.na/57896/environment/mic...
# 257  https://www.standard-freeholder.com/news/local...
# 258  https://www.standard-freeholder.com/news/local...
# 259  https://www.standard-freeholder.com/news/local...
#
#                               Date                     Media  \
# 0    Thu, 23 Jan 2020 08:00:00 GMT  IISD's SDG Knowledge Hub
# 1    Tue, 07 Jan 2020 08:00:00 GMT   IISD Reporting Services
# 2    Thu, 09 Jan 2020 08:00:00 GMT   IISD Reporting Services
# ...

# %%
news_list =[]
for x in range(len(begin_months2019)):
    s = gn.search('intitle:sdg+9', from_ = begin_months2019[x], to_ = end_months2019[x])
    for ind in range(len(s['entries'])):
        dict={}
        article = Article(s['entries'][ind]['link'],config=config)
        article.download()
        try:
            article.parse()
            article.nlp()
            dict['Link'] = s['entries'][ind]['link']
            dict['Date']=s['entries'][ind]['published']
            dict['Media']=s['entries'][ind]['source']['title']
            dict['Title']=article.title
            dict['Article']=article.text
            dict['Summary']=article.summary
            news_list.append(dict) 
        except:
            pass
news_df=pd.DataFrame(news_list)
news_df.to_csv('goognewssdg_9_2019.csv')
news_df
# Out:
#                                                   Link  \
# 0    https://sdg.iisd.org/news/global-goals-website...
# 1    http://sdg.iisd.org/news/co-facilitators-initi...
# 2    http://sdg.iisd.org/news/un-launches-initiativ...
# 3    https://sdg.iisd.org/news/un-campaign-science-...
# 4    http://sdg.iisd.org/news/ungas-2018-work-frame...
# ..                                                 ...
# 234  https://www.thenorthlines.com/jk-gets-20th-ran...
# 235  https://www.standard-freeholder.com/news/local...
# 236      https://esportsobserver.com/v5-sdg-china-lpl/
# 237  https://www.standard-freeholder.com/news/local...
# 238  https://www.standard-freeholder.com/news/local...
#
#                               Date                    Media  \
# 0    Thu, 25 Jan 2018 08:00:00 GMT  IISD Reporting Services
# 1    Tue, 09 Jan 2018 08:00:00 GMT  IISD Reporting Services
# 2    Tue, 09 Jan 2018 08:00:00 GMT  IISD Reporting Services
# ...

# %%
news_list =[]
for x in range(len(begin_months2018)):
    s = gn.search('intitle:sdg+9', from_ = begin_months2018[x], to_ = end_months2018[x])
    for ind in range(len(s['entries'])):
        dict={}
        article = Article(s['entries'][ind]['link'],config=config)
        article.download()
        try:
            article.parse()
            article.nlp()
            dict['Link'] = s['entries'][ind]['link']
            dict['Date']=s['entries'][ind]['published']
            dict['Media']=s['entries'][ind]['source']['title']
            dict['Title']=article.title
            dict['Article']=article.text
            dict['Summary']=article.summary
            news_list.append(dict) 
        except:
            pass
news_df=pd.DataFrame(news_list)
news_df.to_csv('goognewssdg_9_2018.csv')
news_df
# Out:
#                                                   Link  \
# 0    https://sdg.iisd.org/news/global-goals-website...
# 1    http://sdg.iisd.org/news/co-facilitators-initi...
# 2    http://sdg.iisd.org/news/un-launches-initiativ...
# 3    https://sdg.iisd.org/news/un-campaign-science-...
# 4    http://sdg.iisd.org/news/ungas-2018-work-frame...
# ..                                                 ...
# 233  https://www.thenorthlines.com/jk-gets-20th-ran...
# 234  https://www.standard-freeholder.com/news/local...
# 235      https://esportsobserver.com/v5-sdg-china-lpl/
# 236  https://www.standard-freeholder.com/news/local...
# 237  https://www.standard-freeholder.com/news/local...
#
#                               Date                    Media  \
# 0    Thu, 25 Jan 2018 08:00:00 GMT  IISD Reporting Services
# 1    Tue, 09 Jan 2018 08:00:00 GMT  IISD Reporting Services
# 2    Tue, 09 Jan 2018 08:00:00 GMT  IISD Reporting Services
# ...
